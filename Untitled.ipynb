# %%
import pathlib
path_folder = pathlib.Path().resolve()

# %%
import sys  
sys.path.insert(0, str(path_folder)+'/tools/')

# %%
print(path_folder)
# Out:
# /pbs/throng/lsst/users/barcelin/debvader

# %%
import model

# %%
import debvader
import numpy as np

# %%
debvader
# Out:
# <module 'debvader' from '/pbs/throng/lsst/users/barcelin/debvader/debvader/__init__.py'>

# %%
debvader.debvader
# Out:
# <module 'debvader' from '/pbs/throng/lsst/users/barcelin/debvader/debvader/__init__.py'>

# %%
from debvader.debvader import convert, load_deblender, deblend

# %%
convert('test')
# Out:
# I'll convert a notebook for you some day, test.

# %%
nb_of_bands = 6
input_shape = (59, 59, nb_of_bands)
hidden_dim = 256
latent_dim = 32
filters = [32,64,128,256]
kernels = [3,3,3,3]

# %%
net = load_deblender("dc2", input_shape, hidden_dim, latent_dim, filters, kernels)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0727 10:52:36.896291 140108625016640 deprecation.py:506] From /sps/lsst/users/barcelin/miniconda/envs/python_cpu6/lib/python3.6/site-packages/tensorflow_core/python/ops/linalg/linear_operator_lower_triangular.py:158: calling LinearOperator.__init__ (from tensorflow.python.ops.linalg.linear_operator) with graph_parents is deprecated and will be removed in a future version.
# Instructions for updating:
# Do not pass `graph_parents`.  They will  no longer be used.
# in cropping
# /pbs/throng/lsst/users/barcelin/debvader/weights/dc2/

# %%
root_dir = "/pbs/home/b/barcelin/sps_link/data/dc2_test/24.5/test/"
images = np.load(root_dir+'img_cropped_sample_2.npy', mmap_mode = 'c')
images_noiseless = np.load(root_dir+'img_noiseless_sample_2.npy', mmap_mode = 'c')

# %%
images.shape
# Out:
# (10000, 59, 59, 6)

# %%
test_images = images[0:100]
test_images_noiseless = images_noiseless[0:100]

# %%
output = deblend(net, test_images)

# %%
output.shape
# Out:
# (100, 59, 59, 6)

# %%
np.max(test_images[0])
# Out:
# 2.2348599433898926

# %%
np.max(output[0])
# Out:
# 2.2251337

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1,4, figsize =(16,4))

axes[0].imshow(test_images[0,:,:,2])
axes[1].imshow(output[0,:,:,2])
axes[2].imshow(test_images[0,:,:,2]- output[0,:,:,2])
axes[3].imshow(test_images_noiseless[0,:,:,2])

# %%
import scipy

# %%
def diff_deblender(img, deblended_img,nx,ny):
    return img-np.roll(deblended_img,(nx,ny),axis = (0,1))

# %%
out = diff_deblender(test_images[0],output[0],0,0)

# %%
out.shape
# Out:
# (59, 59, 6)

# %%
fig, axes = plt.subplots(1,4, figsize =(16,4))

axes[0].imshow(test_images[0,:,:,2])
axes[1].imshow(output[0,:,:,2])
axes[2].imshow(test_images[0,:,:,2]- output[0,:,:,2])
axes[3].imshow(out[:,:,2])

# %%
from scipy import optimize

# %%
import scipy

# %%
fig, axes = plt.subplots(1,5, figsize= (20,4))

axes[0].imshow(test_images[7,:,:,2])
axes[1].imshow(output[7,:,:,2])
axes[2].imshow(test_images[7,:,:,2]-output[7,:,:,2])
axes[3].imshow(test_images[7,:,:,2]-np.roll(output[7,:,:,2],shift = 2,axis = (0,1)))

axes[4].imshow(test_images[7,:,:,2]-scipy.ndimage.shift(output[7,:,:,2],shift = (0.3,0.3)))


print(np.min(test_images[7,:,:,2]-output[7,:,:,2]), np.min(test_images[7,:,:,2]-scipy.ndimage.shift(output[7,:,:,2],shift = (0.3,0.3))))
# Out:
# -0.4180753231048584 -0.13714289665222168

# %%
def fun (x, test_img, output): 
    return 1/skimage.measure.compare_ssim(test_img,scipy.ndimage.shift(output,shift = (x[0],x[1])))

# %%
bnds = ((-2, 2), (-2, 2))

list_x = []

for i in range (50):
    #opt = optimize.minimize(fun,(0.,0.),method='SLSQP',args=(test_images[i,:,:,2],output[i,:,:,2]), bounds=bnds, tol=1e-1)
    opt = optimize.least_squares(fun,(0.,0.), args=(test_images[i,:,:,2],output[i,:,:,2]), bounds=(-2,2))
    #print(opt.message)
    print(opt.x)
    list_x.append(opt.x)
# Out:
# [-0.45678403  0.69467943]
# [-0.40744884 -0.09576401]
# [-0.09417709  0.07697885]
# [-0.12174392 -0.23686749]
# [-2.12394346e-07 -5.21442492e-06]
# [ 1.39426335e-08 -1.58016512e-08]
# [-0.62418876 -0.25176809]
# [0.23856373 0.40899076]
# [-1.15134929e-15  5.02112151e-16]
# [-0.08005251  0.69946878]
# [-0.60029872 -0.20706131]
# [ 3.40280056e-17 -1.25561296e-15]
# [0. 0.]
# [-1.26896339e-08  1.68244584e-08]
# [0. 0.]
# [ 0.26199319 -0.33702638]
# [-2.05716041e-08  4.57146761e-09]
# [7.02777018e-05 3.30739317e-08]
# [-8.16220737e-06  6.55219717e-05]
# [-7.56491848e-09 -1.96687879e-08]
# [-0.01665611 -0.38963438]
# [ 4.06388543e-09 -1.77207322e-08]
# [ 0.15003189 -0.23409705]
# [-0.0319726  -0.73967658]
# [-2.65042409e-07 -2.89299409e-08]
# [-0.02060959 -0.00660678]
# [-1.77079278e-08  1.14244696e-08]
# [-0.30279731  0.09012026]
# [-0.01470631 -0.15217119]
# [0. 0.]
# [-1.10742782e-15  5.92727110e-16]
# [0.14891977 0.40835491]
# [-1.22753635e-15  2.66226046e-16]
# [-0.20317668  0.26220649]
# [-0.00938992  0.06205643]
# [-0.31424321 -0.04747902]
# [0. 0.]
# [ 8.11253373e-08 -1.08561236e-06]
# [-0.69382018 -0.72377821]
# [ 5.46423963e-16 -1.13099189e-15]
# [6.87269019e-08 1.89743913e-05]
# [0. 0.]
# [ 0.35855939 -0.27870078]
# [0. 0.]
# [-0.07222767 -0.03972966]
# [-0.2178104   0.14662923]
# [-0.0001981   0.00020313]
# [0. 0.]
# [-6.55630856e-08 -5.29802715e-08]
# [0.06346626 0.06151857]

# %%
fig, axes = plt.subplots(50,4, figsize= (16,200))

for i in range (50):
    axes[i,0].imshow(test_images[i,:,:,2])
    axes[i,1].imshow(output[i,:,:,2])
    axes[i,2].imshow(test_images[i,:,:,2]-output[i,:,:,2])
    axes[i,3].imshow(test_images[i,:,:,2]-scipy.ndimage.shift(output[i,:,:,2],shift = list_x[i]))


print(np.min(test_images[7,:,:,2]-output[7,:,:,2]), np.min(test_images[7,:,:,2]-scipy.ndimage.shift(output[7,:,:,2],shift = list_x[7])))
# Out:
# -0.4180753231048584 -0.1655064821243286

# %%
fig, axes = plt.subplots(1,4, figsize =(16,4))

axes[0].imshow(test_images[0,:,:,2])
axes[1].imshow(output[0,:,:,2])
axes[2].imshow(test_images[0,:,:,2]- np.roll(output[0,:,:,2],(0,0),axis = (0,1)))
axes[3].imshow(out[:,:,2])
